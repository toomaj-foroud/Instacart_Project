# %% [markdown]
# ## Import libraries and data frames

# %%
# import libraries

import numpy as np
import pandas as pd
import os

# %%
# import data frames 'orders' & 'products'
path = r'C:\Users\98912\MAY 2022 Instacart Analysis'

df_ords = pd.read_csv(os.path.join(path, '02-Data', 'Original Data', 'orders.csv'), index_col=False)
df_prods = pd.read_csv(os.path.join(path, '02-Data', 'Original Data', 'products.csv'), index_col=False)

# %% [markdown]
# ## Data wrangling

# %%
# remove eval_set from orders
df_ords = df_ords.drop(columns=['eval_set'])
df_ords.head()
# Out:
#    order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1             1          2                  8
# 1   2398795        1             2          3                  7
# 2    473747        1             3          3                 12
# 3   2254736        1             4          4                  7
# 4    431534        1             5          4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %%
# count the number of each value in different variable (here:'days_since_prior_order')
df_ords['days_since_prior_order'].value_counts(dropna=False)
# Out:
# 30.0    369323
# 7.0     320608
# 6.0     240013
# 4.0     221696
# 3.0     217005
# 5.0     214503
# NaN     206209
# 2.0     193206
# 8.0     181717
# 1.0     145247
# 9.0     118188
# 14.0    100230
# 10.0     95186
# 13.0     83214
# 11.0     80970
# 12.0     76146
# 0.0      67755
# 15.0     66579
# 16.0     46941
# 21.0     45470
# 17.0     39245
# 20.0     38527
# 18.0     35881
# 19.0     34384
# 22.0     32012
# 28.0     26777
# 23.0     23885
# 27.0     22013
# 24.0     20712
# 25.0     19234
# 29.0     19191
# 26.0     19016
# Name: days_since_prior_order, dtype: int64

# %%
# rename a column
df_ords.rename(columns = {'order_dow':'order_day_of_week'}, inplace=True)
df_ords.head()
# Out:
#    order_id  user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                  2                  8
# 1   2398795        1             2                  3                  7
# 2    473747        1             3                  3                 12
# 3   2254736        1             4                  4                  7
# 4    431534        1             5                  4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %%
df_ords.dtypes
# Out:
# order_id                    int64
# user_id                     int64
# order_number                int64
# order_day_of_week           int64
# order_hour_of_day           int64
# days_since_prior_order    float64
# dtype: object

# %%
# changing variable data type
df_ords['order_id'] = df_ords['order_id'].astype('str')
df_ords.dtypes
# Out:
# order_id                   object
# user_id                     int64
# order_number                int64
# order_day_of_week           int64
# order_hour_of_day           int64
# days_since_prior_order    float64
# dtype: object

# %% [markdown]
# ## Department data set

# %%
df_dep = pd.read_csv(os.path.join(path, '02-Data', 'Original Data', 'departments.csv'), index_col=False)

# %%
df_dep.head()
# Out:
#   department_id       1      2       3        4        5              6  \
# 0    department  frozen  other  bakery  produce  alcohol  international
#
#            7     8                9  ...            12      13         14  \
# 0  beverages  pets  dry goods pasta  ...  meat seafood  pantry  breakfast
#
#              15          16         17      18      19    20       21
# 0  canned goods  dairy eggs  household  babies  snacks  deli  missing
#
# [1 rows x 22 columns]

# %% [markdown]
# ## Transposing data

# %%
# transpose data column
df_dep_T = df_dep.T
df_dep_T
# Out:
#                              0
# department_id       department
# 1                       frozen
# 2                        other
# 3                       bakery
# 4                      produce
# 5                      alcohol
# 6                international
# 7                    beverages
# 8                         pets
# 9              dry goods pasta
# 10                        bulk
# 11               personal care
# 12                meat seafood
# 13                      pantry
# 14                   breakfast
# 15                canned goods
# 16                  dairy eggs
# 17                   household
# 18                      babies
# 19                      snacks
# 20                        deli
# 21                     missing

# %%
# creat new index column
df_dep_T.reset_index()
# Out:
#             index                0
# 0   department_id       department
# 1               1           frozen
# 2               2            other
# 3               3           bakery
# 4               4          produce
# 5               5          alcohol
# 6               6    international
# 7               7        beverages
# 8               8             pets
# 9               9  dry goods pasta
# 10             10             bulk
# 11             11    personal care
# 12             12     meat seafood
# 13             13           pantry
# 14             14        breakfast
# 15             15     canned goods
# 16             16       dairy eggs
# 17             17        household
# 18             18           babies
# 19             19           snacks
# 20             20             deli
# 21             21          missing

# %%
# define new header row
new_header = df_dep_T.iloc[0]

# %%
new_header
# Out:
# 0    department
# Name: department_id, dtype: object

# %%
# remove the first row from data frame
df_dep_T_new = df_dep_T[1:]

# %%
df_dep_T_new
# Out:
#                   0
# 1            frozen
# 2             other
# 3            bakery
# 4           produce
# 5           alcohol
# 6     international
# 7         beverages
# 8              pets
# 9   dry goods pasta
# 10             bulk
# 11    personal care
# 12     meat seafood
# 13           pantry
# 14        breakfast
# 15     canned goods
# 16       dairy eggs
# 17        household
# 18           babies
# 19           snacks
# 20             deli
# 21          missing

# %%
df_dep_T_new.columns = new_header

# %%
df_dep_T_new
# Out:
# department_id       department
# 1                       frozen
# 2                        other
# 3                       bakery
# 4                      produce
# 5                      alcohol
# 6                international
# 7                    beverages
# 8                         pets
# 9              dry goods pasta
# 10                        bulk
# 11               personal care
# 12                meat seafood
# 13                      pantry
# 14                   breakfast
# 15                canned goods
# 16                  dairy eggs
# 17                   household
# 18                      babies
# 19                      snacks
# 20                        deli
# 21                     missing

# %% [markdown]
# ## Data dictionary

# %%
# create dictionary from fataframe
data_dict = df_dep_T_new.to_dict('index')

# %%
data_dict
# Out:
# {'1': {'department': 'frozen'},
#  '2': {'department': 'other'},
#  '3': {'department': 'bakery'},
#  '4': {'department': 'produce'},
#  '5': {'department': 'alcohol'},
#  '6': {'department': 'international'},
#  '7': {'department': 'beverages'},
#  '8': {'department': 'pets'},
#  '9': {'department': 'dry goods pasta'},
#  '10': {'department': 'bulk'},
#  '11': {'department': 'personal care'},
#  '12': {'department': 'meat seafood'},
#  '13': {'department': 'pantry'},
#  '14': {'department': 'breakfast'},
#  '15': {'department': 'canned goods'},
#  '16': {'department': 'dairy eggs'},
#  '17': {'department': 'household'},
#  '18': {'department': 'babies'},
#  '19': {'department': 'snacks'},
#  '20': {'department': 'deli'},
#  '21': {'department': 'missing'}}

# %%
df_prods.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id  prices
# 0             19     5.8
# 1             13     9.3
# 2              7     4.5
# 3              1    10.5
# 4             13     4.3

# %%
data_dict.get('19')
# Out:
# {'department': 'snacks'}

# %% [markdown]
# ## subsetting

# %%
df_snacks =  df_prods[df_prods['department_id']==19]

# %%
df_snacks.head()
# Out:
#     product_id                                 product_name  aisle_id  \
# 0            1                   Chocolate Sandwich Cookies        61
# 15          16                Mint Chocolate Flavored Syrup       103
# 24          25      Salted Caramel Lean Protein & Fiber Bar         3
# 31          32                Nacho Cheese White Bean Chips       107
# 40          41  Organic Sourdough Einkorn Crackers Rosemary        78
#
#     department_id  prices
# 0              19     5.8
# 15             19     5.2
# 24             19     1.9
# 31             19     4.9
# 40             19     6.5

# %% [markdown]
# # Task Steps

# %%
# step 2: change data type of 'user_id' to 'str'
df_ords['user_id'] = df_ords['user_id'].astype('str')
df_ords.dtypes
# Out:
# order_id                   object
# user_id                    object
# order_number                int64
# order_day_of_week           int64
# order_hour_of_day           int64
# days_since_prior_order    float64
# dtype: object

# %%
# step 3: change the name of 'order_number' to 'order_quantity'
df_ords.rename(columns = {'order_number':'order_quantity'}, inplace=False)
# Out:
#         order_id user_id  order_quantity  order_day_of_week  \
# 0        2539329       1               1                  2
# 1        2398795       1               2                  3
# 2         473747       1               3                  3
# 3        2254736       1               4                  4
# 4         431534       1               5                  4
# ...          ...     ...             ...                ...
# 3421078  2266710  206209              10                  5
# 3421079  1854736  206209              11                  4
# 3421080   626363  206209              12                  1
# 3421081  2977660  206209              13                  1
# 3421082   272231  206209              14                  6
#
#          order_hour_of_day  days_since_prior_order
# 0                        8                     NaN
# 1                        7                    15.0
# 2                       12                    21.0
# ...

# %%
# when we use 'inplace=False' the changes will not be save in the dataframe
df_ords
# Out:
#         order_id user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0        2539329       1             1                  2                  8
# 1        2398795       1             2                  3                  7
# 2         473747       1             3                  3                 12
# 3        2254736       1             4                  4                  7
# 4         431534       1             5                  4                 15
# ...          ...     ...           ...                ...                ...
# 3421078  2266710  206209            10                  5                 18
# 3421079  1854736  206209            11                  4                 10
# 3421080   626363  206209            12                  1                 12
# 3421081  2977660  206209            13                  1                 12
# 3421082   272231  206209            14                  6                 14
#
#          days_since_prior_order
# ...

# %%
# step 4: find the frequency of orders in each hour of day
# according to these results busiest hours for putting orders are "10" & "11". and the least busiest hours are "3" & "4"
df_ords['order_hour_of_day'].value_counts()
# Out:
# 10    288418
# 11    284728
# 15    283639
# 14    283042
# 13    277999
# 12    272841
# 16    272553
# 9     257812
# 17    228795
# 18    182912
# 8     178201
# 19    140569
# 20    104292
# 7      91868
# 21     78109
# 22     61468
# 23     40043
# 6      30529
# 0      22758
# 1      12398
# 5       9569
# 2       7539
# 4       5527
# 3       5474
# Name: order_hour_of_day, dtype: int64

# %%
# step 5: setermine the meaning of '4' for department_id (it means 'produce' department)
data_dict.get('4')
# Out:
# {'department': 'produce'}

# %%
# step 6: breakfast item are equivalent with '14' as deprtment_id in df_prods dataframe
df_breakfast = df_prods[df_prods['department_id']==14]
df_breakfast.head()
# Out:
#      product_id                                      product_name  aisle_id  \
# 27           28                                 Wheat Chex Cereal       121
# 33           34                                               NaN       121
# 67           68                           Pancake Mix, Buttermilk       130
# 89           90                                      Smorz Cereal       121
# 210         211  Gluten Free Organic Cereal Coconut Maple Vanilla       130
#
#      department_id  prices
# 27              14    10.1
# 33              14    12.2
# 67              14    13.7
# 89              14     3.9
# 210             14     3.6

# %%
# step 7:  alcohol=5, deli=20, beverage=7, meat/seafood=12

# first we get the department_id of the requested departments
R = [{'department': 'alcohol'}, {'department': 'deli'}, {'department': 'beverages'}, {'department': 'meat seafood'}]
indexes = [i for i,l in enumerate(list(data_dict.values())) if l in R]
dep_id = list(np.array(list(data_dict.keys()))[indexes])
# convert the 'str' to 'int'
dep_id = [int(i) for i in dep_id]
dep_id
# Out:
# [5, 7, 12, 20]

# %%
# now we separate a subset of df_prods to include just these departments
df_dinner_party = df_prods[df_prods['department_id'].isin(dep_id) ]
df_dinner_party
# Out:
#        product_id                                    product_name  aisle_id  \
# 2               3            Robust Golden Unsweetened Oolong Tea        94
# 6               7                  Pure Coconut Water With Orange        98
# 9              10  Sparkling Orange Juice & Prickly Pear Beverage       115
# 10             11                               Peach Mango Juice        31
# 16             17                               Rendered Duck Fat        35
# ...           ...                                             ...       ...
# 49676       49672                          Cafe Mocha K-Cup Packs        26
# 49679       49675             Cinnamon Dolce Keurig Brewed K Cups        26
# 49680       49676                          Ultra Red Energy Drink        64
# 49686       49682                              California Limeade        98
# 49688       49684       Vodka, Triple Distilled, Twist of Vanilla       124
#
#        department_id  prices
# ...

# %%
# part 8: the shape of df_dinner_party (7650, 5)
df_dinner_part.shape
# Out:
# (7650, 5)

# %%
# part 9: extract information for user_id=1
df_user_1 = df_ords[df_ords['user_id']=='1']
df_user_1
# Out:
#    order_id user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0   2539329       1             1                  2                  8
# 1   2398795       1             2                  3                  7
# 2    473747       1             3                  3                 12
# 3   2254736       1             4                  4                  7
# 4    431534       1             5                  4                 15
# 5   3367565       1             6                  2                  7
# 6    550135       1             7                  1                  9
# 7   3108588       1             8                  1                 14
# 8   2295261       1             9                  1                 16
# 9   2550362       1            10                  4                  8
# 10  1187899       1            11                  4                  8
#
#     days_since_prior_order
# 0                      NaN
# 1                     15.0
# ...

# %%
# part 10: some statistics for user_id=1
df_user_1.describe()
# Out:
#        order_number  order_day_of_week  order_hour_of_day  \
# count     11.000000          11.000000          11.000000
# mean       6.000000           2.636364          10.090909
# std        3.316625           1.286291           3.477198
# min        1.000000           1.000000           7.000000
# 25%        3.500000           1.500000           7.500000
# 50%        6.000000           3.000000           8.000000
# 75%        8.500000           4.000000          13.000000
# max       11.000000           4.000000          16.000000
#
#        days_since_prior_order
# count               10.000000
# mean                19.000000
# std                  9.030811
# min                  0.000000
# 25%                 14.250000
# 50%                 19.500000
# 75%                 26.250000
# max                 30.000000

# %%
# step 12: export 'df_ords' as 'orders_wrangled.csv'
df_ords.to_csv(os.path.join(path, '02-Data', 'Prepared Data', 'orders_wrangled.csv'))

# %%
# step 13: export 'df_dep_T_new' as 'departments_wrangled.csv'
df_dep_T_new.to_csv(os.path.join(path, '02-Data', 'Prepared Data', 'departments_wrangled.csv'))
